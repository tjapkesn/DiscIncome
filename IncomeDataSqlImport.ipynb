# %%
import pandas as pd

# %%
IncomeData = pd.read_csv('Data/wiid-data(2).csv', delimiter = ';')

# %%
IncomeData
# Out:
#                                            ISO  \
# 0                                          ABW
# 1                                          AFG
# 2                                          AGO
# 3                                          AIA
# 4                                          ALB
# ..                                         ...
# 211  region_wb-latin_america_and_the_caribbean
# 212     region_wb-middle_east_and_north_africa
# 213                    region_wb-north_america
# 214                       region_wb-south_asia
# 215               region_wb-sub_saharan_africa
#
#                              COUNTRY  YEAR  GINI INDEX  M-THEIL, GE(0)  \
# 0                              Aruba  2019      48.390          41.630
# 1                        Afghanistan  2019      45.125          34.745
# 2                             Angola  2019      62.420          86.832
# 3                           Anguilla  2019      48.390          41.630
# ...

# %%
IncomeData = IncomeData.drop(['ISO'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 IncomeData = IncomeData.drop(['ISO'], axis =1)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
import sqlalchemy

# %%
from sqlalchemy import engine

# %%
engine  = sqlalchemy.create_engine('postgresql://postgres:B3p1s0k.@localhost:5432/mydb')

# %%
IncomeData.to_sql('income_data', engine, if_exists= 'replace', index = False)
# Out:
# 216
