# %%
import pandas as pd

# %%
stateandlocal = pd.read_csv('Data/TABLE_I2_09072023011321643.csv')

# %%
stateandlocal
# Out:
#      COU        Country LEVEL_GOV Level of government TAX_BASE Tax base  \
# 0    DNK        Denmark         S                   S       TY       TY
# 1    DNK        Denmark         S                   S       TY       TY
# 2    DNK        Denmark         S                   S       TY       TY
# 3    DNK        Denmark         S                   S       TY       TY
# 4    DNK        Denmark         S                   S       TY       TY
# ..   ...            ...       ...                 ...      ...      ...
# 726  USA  United States         L                   L      TYS      TYs
# 727  USA  United States         L                   L      TYS      TYs
# 728  USA  United States         L                   L      TYS      TYs
# 729  USA  United States         L                   L      TYS      TYs
# 730  USA  United States         L                   L      TYS      TYs
#
#     SUBGOV_RATES     Sub-central tax rates   YEA  Year Unit Code        Unit  \
# ...

# %%
stateandlocal = stateandlocal.drop(['COU',
        'LEVEL_GOV', 'TAX_BASE', 'SUBGOV_RATES','YEA',
       'Unit Code', 'PowerCode Code', 'PowerCode',
       'Reference Period Code', 'Flag Codes',
       'Flags'], axis =1)

# %%
stateandlocal[stateandlocal['Year'] == 2019]['Country'].unique()
# Out:
# array(['Denmark', 'Finland', 'Iceland ', 'Italy', 'Japan', 'Korea',
#        'Norway', 'Sweden ', 'United States'], dtype=object)

# %%
import sqlalchemy

# %%
from sqlalchemy import engine

# %%
engine  = sqlalchemy.create_engine('postgresql://postgres:B3p1s0k.@localhost:5432/mydb')

# %%
stateandlocal.to_sql('state_local_tax_flat', engine, if_exists= 'replace', index = False)
# Out:
# 731
