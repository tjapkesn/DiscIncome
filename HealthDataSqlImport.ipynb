# %%
import pandas as pd

# %%
Rent = pd.read_excel('Data/statistic_id236541_per-capita-health-expenditure-in-selected-countries-2021.xlsx', sheet_name= 1)

# %%
Rent
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2
# 0          NaN                                                NaN         NaN
# 1          NaN  Per capita health expenditure in selected coun...         NaN
# 2          NaN  Per capita health expenditure in selected coun...         NaN
# 3          NaN                                                NaN         NaN
# 4          NaN                                      United States     12318.1
# 5          NaN                                            Germany      7382.6
# 6          NaN                                        Switzerland      7178.6
# 7          NaN                                             Norway      7064.8
# 8          NaN                                        Netherlands      6752.8
# 9          NaN                                            Austria      6693.3
# 10         NaN                                            Denmark      6384.2
# ...

# %%
Rent = Rent.drop(range(4))

# %%
Rent = Rent.drop(['Unnamed: 0'], axis =1)

# %%
Rent.columns = ['country', 'health_spending_per_capita']

# %%
Rent
# Out:
#             country  health_spending_per_capita
# 4     United States                     12318.1
# 5           Germany                      7382.6
# 6       Switzerland                      7178.6
# 7            Norway                      7064.8
# 8       Netherlands                      6752.8
# 9           Austria                      6693.3
# 10          Denmark                      6384.2
# 11           Sweden                      6262.3
# 12           France                      6114.9
# 13           Canada                      5904.9
# 14          Ireland                      5836.3
# 15       Luxembourg                      5628.5
# 16        Australia                      5627.3
# 17          Belgium                      5407.0
# 18   United Kingdom                      5387.2
# 19          Iceland                      5096.4
# 20            Japan                      4665.6
# 21          Finland                      4604.6
# 22      New Zealand                      4469.4
# ...

# %%
import sqlalchemy

# %%
from sqlalchemy import engine

# %%
engine  = sqlalchemy.create_engine('postgresql://postgres:B3p1s0k.@localhost:5432/mydb')

# %%
Rent.to_sql('health_spending', engine, if_exists= 'replace', index = False)
# Out:
# 45
